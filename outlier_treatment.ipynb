# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.shape
# Out:
# (3678, 23)

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (426,
#  count    426.000000
#  mean       9.227089
#  std        4.064292
#  min        5.460000
#  25%        6.445000
#  50%        8.000000
#  75%       10.702500
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 1003         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3740         house                                        independent
# 3254         house                                     dlf city plots
# 1682         house                                        independent
# 1235         house                                   suncity township
# 1444         house                             emaar the palm springs
# 3720         house                                        independent
# 3707         house                                 vipul tatvam villa
# 597          house                             luxury dlf city floors
# 910          house                                        independent
# 2031         house                                     dlf city plots
# 2686         house                                        independent
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (353,
#  count       353.000000
#  mean      52672.226629
#  std       61218.883253
#  min       24500.000000
#  25%       28233.000000
#  50%       33404.000000
#  75%       42032.000000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      353.000000
# mean     29371.696884
# std      12417.964865
# min       2723.000000
# 25%      25562.000000
# 50%      29880.000000
# 75%      35556.000000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 245          house                   independent        sector 26  14.75
# 278          house  project housing board colony        sector 31   8.00
# 795          house                   independent        sector 25  16.00
# 877           flat                unitech vistas        sector 70   9.00
# 1072         house            emaar mgf marbella        sector 66  18.00
# 1328         house                           nul        sector 28  12.50
# 1444         house        emaar the palm springs        sector 54  24.00
# 1451         house        emaar the palm springs        sector 54  14.00
# 1682         house                   independent        sector 26  26.00
# 2090         house            cloudnine cottages  sohna road road   5.50
# 2480         house                unitech escape        sector 50  10.80
# 2582         house                  malibu towne        sector 47   8.50
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ## area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 664           flat            ramsons kshitij   sector 95   0.31
# 847          house                independent   sector 50   5.00
# 988           flat      signature the roselia   sector 95   0.45
# 1002          flat          hcbs sports ville  sohna road   0.35
# 2319          flat  signature global solera 2  sector 107   0.51
#
#       price_per_sqft      area                           areaWithType  \
# 664              5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 847            232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 988              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1002             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2319             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 664         2         2       1       1.0  North-East  Relatively New
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
#3158,2507,3610,2977,2527,541,3413,2938,1205
# Out:
#      property_type                    society           sector  price  \
# 3158         house                independent        sector 26  18.40
# 1268         house  ganpati heights apartment        sector 13   1.25
# 2507          flat                 rof ananda        sector 95   0.38
# 3610          flat                 rof ananda        sector 95   0.38
# 3779         house      dlf city plot phase 4        sector 28  13.00
# 2977          flat              pyramid elite        sector 86   0.46
# 2527          flat                 rof ananda        sector 95   0.33
# 541           flat      signature the serenas       sohna road   0.28
# 2715         house                independent        sector 25   7.30
# 3413          flat            ramsons kshitij        sector 95   0.24
# 2938          flat                 rof ananda        sector 95   0.21
# 168          house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[3158,2507,3610,2977,2527,541,3413,2938,1205], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 1268         house  ganpati heights apartment        sector 13   1.25
# 3779         house      dlf city plot phase 4        sector 28  13.00
# 2715         house                independent        sector 25   7.30
# 168          house                independent        sector 57   6.25
# 2832         house                independent        sector 43   5.50
# 2172          flat                 godrej air        sector 85   2.50
# 1018         house       unitech aspen greens        sector 50   6.95
# 2300          flat                godrej icon       sector 88a   1.75
# 3740         house                independent        sector 43  27.50
# 2459          flat             m3m golfestate        sector 65  13.20
# 157          house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 1268           151.0  82781.0
# 3779          1992.0  65261.0
# 2715          1560.0  46795.0
# ...

# %%
df.loc[1268,'area'] = 115*9
df.loc[3779,'area'] = 7250
df.loc[2715,'area'] = 5800
df.loc[168,'area'] = 2660
df.loc[2832,'area'] = 2850
df.loc[2172,'area'] = 1812
df.loc[1018,'area'] = 2160
df.loc[2300,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %% [markdown]
# ## bedroom

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3589, 23)

# %% [markdown]
# ## bathroom

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %% [markdown]
# ## superbuiltuparea

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1214          flat       krrish provence estate  gwal pahari    7.5
# 2306          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 1214          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 2306          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1214        5         6      3+      23.0  North-East  Relatively New
# 2306        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1214              10000.0            NaN          NaN           0
# 2306               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ## builtuparea

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 3740         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3740  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 3740  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3740          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 3740                0            42

# %% [markdown]
# ## carpetarea

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2172          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2459          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2172  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 2459  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 2172  North-East  Under Construction                  NaN            NaN
# 2459       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2172      18122.0           1             0           0           1       1
# 2459      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2172,'carpet_area'] = 1812

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15428\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 486          house  sushant lok 1 builder floors   sector 43   13.0
# 703          house                   independent   sector 43    9.5
# 883          house                   independent   sector 55    5.0
# 910          house                   independent   sector 26   20.0
# 2121         house                   independent   sector 26   19.0
# 2193         house                   independent   sector 28   12.0
# 2567         house                   independent  sector 105    9.9
# 2587         house                   independent   sector 25   13.0
# 3579         house                dlf city plots   sector 26   19.0
#
#       price_per_sqft    area  \
# 486          48148.0  2700.0
# 703          42222.0  2250.0
# 883          44444.0  1125.0
# 910          44444.0  4500.0
# 2121         42222.0  4500.0
# 2193         42194.0  2844.0
# 2567         49500.0  2000.0
# 2587         45710.0  2844.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250].sample(5)
# Out:
#      property_type                  society      sector  price  \
# 2725          flat               mvn athens   sector 90   0.27
# 680           flat              tulip lemon   sector 69   0.62
# 3614         house              independent   sector 28   0.45
# 3815         house              independent  sector 105   1.20
# 3804          flat  signature global solera  sector 107   0.50
#
#       price_per_sqft   area                      areaWithType  bedRoom  \
# 2725          5895.0  458.0  Carpet area: 457.52 (42.5 sq.m.)        2
# 680          12863.0  482.0    Carpet area: 482 (44.78 sq.m.)        2
# 3614         10000.0  450.0    Built Up area: 50 (4.65 sq.m.)        5
# 3815         13333.0  900.0        Plot area 900(83.61 sq.m.)        7
# 3804          7752.0  645.0    Carpet area: 645 (59.92 sq.m.)        3
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 2725         2       1       0.0         NaN  Relatively New
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df=df[df['area_room_ratio']>100]

# %%
outlier_df=df[df['area_room_ratio']<250 &(df['bedRoom']>3)]

# %%
outlier_df['bedRoom']=round(outlier_df['bedRoom']/outlier_df['floorNum'])

# %%
df.update(outlier_df)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.shape
# Out:
# (3496, 24)

# %%
df.to_csv('gurgaon_property_outlier_treated.csv',index=False)
